# %%
#Strings
s = 'hi'
t = "hello"
x = "said 'hello'"
print(s[1])          ## i
print(len(x))        ## 2
print(s + " " + 'there')  ## hi there
# Out:
# i
# 12
# hi there

# %%
pi = 3.14
text = 'The value of pi is ' + pi      ## NO, does not work
text = 'The value of pi is '  + str(pi)  ## yes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-67cd850288a2> in <module>()
#       1 pi = 3.14
# ----> 2 text = 'The value of pi is ' + pi      ## NO, does not work
#       3 text = 'The value of pi is '  + str(pi)  ## yes
#
# TypeError: must be str, not float

# %%
raw = r'this\t\n and that'

# this\t\n and that
print(raw)

not_raw = 'this\t\n and that'
print(not_raw)

multi_line = '''It was the best of times.
It was the worst of times.'''
# It was the best of times.
#   It was the worst of times.
print(multi_line)
# Out:
# this\t\n and that
# this
#  and that
# It was the best of times.
# It was the worst of times.

# %%
#String methods
#s.lower(), s.upper(), s.strip(), s.isalpha(), s.isdigit(), s.isspace(), s.startswith('other'), s.endswith('other')
#s.find('other'), s.replace('old', 'new'), s.split('delim'), s.join(list) e.g '---'.join(['aaa', 'bbb', 'ccc'])

# %%
print("Cal State San Marcos".strip().split("#"))
# Out:
# ['Cal State San Marcos']

# %%
s = "Calstate san marcos is located at san Marcos"
print(s.split("#"))
# Out:
# ['Calstate san marcos is located at san Marcos']

# %%
#String Slices
s ="Calstate San Marcos"
s[1:4]
s[-1]
s[:-1]
# Out:
# 'Calstate San Marco'

# %%
#String %
#(%d => int, %s =>string, %f/%g =>floating point

x = "%d %s is %f %s" %(1, "dollar", 105.40, "yen")
print(x)
# Out:
# 1 dollar is 105.400000 yen
