# %%
import IPython
url = 'https://newevolutiondesigns.com/images/freebies/colorful-background-14.jpg'
IPython.display.Image(url, width = 200)

# %%
from IPython.display import YouTubeVideo
vid = YouTubeVideo('Qkuu0Lwb5EM', width=640, height=480, start=20, autoplay=1)
display(vid)
