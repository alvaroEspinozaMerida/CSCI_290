# %%
import urllib.request

link = "ftp://ftp.nasdaqtrader.com/symboldirectory/nasdaqlisted.txt"
file = urllib.request.urlopen(link)
stock ={}
for line in file:
    line = file.readline()
    decoded = line.decode("utf-8")
    splitted = decoded.split("|")
    if len(splitted) > 1:
        print(len(splitted))
        stock[splitted[0]] = splitted[1]
        
        print(splitted[0], "=>", splitted[1])
# Out:
# 8
# AACG => ATA Creativity Global - American Depositary Shares, each representing two common shares
# 8
# AACIU => Armada Acquisition Corp. I - Unit
# 8
# AADI => Aadi Bioscience, Inc. - Common Stock
# 8
# AAL => American Airlines Group, Inc. - Common Stock
# 8
# AAOI => Applied Optoelectronics, Inc. - Common Stock
# 8
# AAPB => GraniteShares 1.75x Long AAPL Daily ETF
# 8
# AAPL => Apple Inc. - Common Stock
# 8
# AAWW => Atlas Air Worldwide Holdings - Common Stock
# 8
# ABCB => Ameris Bancorp - Common Stock
# 8
# ABCM => Abcam plc - American Depositary Shares
# 8
# ABGI => ABG Acquisition Corp. I - Class A Ordinary Shares
# 8
# ABNB => Airbnb, Inc. - Class A Common Stock
# 8
# ABSI => Absci Corporation - Common Stock
# 8
# ABUS => Arbutus Biopharma Corporation - Common Stock
# 8
# ACAB => Atlantic Coastal Acquisition Corp. II - Class A Common Stock
# 8
# ACABW => Atlantic Coastal Acquisition Corp. II - Warrant
# 8
# ACACU => Acri Capital Acquisition Corporation - Unit
# 8
# ...
